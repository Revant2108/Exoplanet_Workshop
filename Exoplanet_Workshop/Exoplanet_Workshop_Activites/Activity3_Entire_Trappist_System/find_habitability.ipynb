# %%
# Final Activity

# Run cells one by one. 
# Run this cell to understand your final activity
print("="*70)
print("🌍 FINAL MISSION: THE GOLDILOCKS ZONE")
print("="*70)
print("\nBACKGROUND:")
print("• You've found TRAPPIST-1b & c (too hot for life)")
print("• NOW find planets d, e, f in the 'Habitable Zone'")
print("• This zone = where liquid water could exist!")
print("\nYOUR TASK:")
print("1. Identify which periods belong to habitable planets")
print("2. Analyze their temperatures and life potential")
print("3. Connect to REAL science happening now (JWST telescope!)")
print("\n⏱️ TIME: 15 minutes")
print("="*70)
# Out:
# ======================================================================
# 🌍 FINAL MISSION: THE GOLDILOCKS ZONE
# ======================================================================
#
# BACKGROUND:
# • You've found TRAPPIST-1b & c (too hot for life)
# • NOW find planets d, e, f in the 'Habitable Zone'
# • This zone = where liquid water could exist!
#
# YOUR TASK:
# 1. Identify which periods belong to habitable planets
# 2. Analyze their temperatures and life potential
# 3. Connect to REAL science happening now (JWST telescope!)
#
# ⏱️ TIME: 15 minutes
# ======================================================================

# %%
# Student Notebook - ULTRA SIMPLE

# ============================================
# STEP 1: ONE LINE TO START EVERYTHING!
# ============================================

from trappist_habitable import TRAPPISTHabitable

# That's it! Data loads automatically
mission = TRAPPISTHabitable()

#  SEE THE DATA

mission.visualize_data()

print("\nDiscuss with partner: What do you notice about the data info above?")
print("\n🛑 STOP - Discuss (2 minutes):")
print("1. What patterns do you see in the light curve?")
print("2. How is this different from the Kepler-22b data?")
# Out:
# ✅ Data loaded from: trappist_jwst_data.csv
# ======================================================================
# 🌍 TRAPPIST-1 HABITABLE ZONE MISSION
# ======================================================================
#
# ✅ Mission initialized and ready!
# 📊 Data loaded: 20,000 points
# 📅 Time range: 0.0 to 60.0 days
#
# Use these simple commands:
# • mission.visualize_data()
# • mission.find_habitable_periods()
# • mission.run_habitability_dashboard()
# ======================================================================
# 🔍 DATA INTERPRETATION GUIDE:
# • Each dot = one brightness measurement
# • Dips = planets transiting (blocking starlight)
# • Multiple overlapping dips = 7 planets!
# • Your challenge: Find the habitable ones
#
# Discuss with partner: What do you notice about the data info above?
#
# 🛑 STOP - Discuss (2 minutes):
# 1. What patterns do you see in the light curve?
# 2. How is this different from the Kepler-22b data?

# %%
# ============================================
# STEP 2: FIND HABITABLE PLANETS
# ============================================

mission.find_habitable_periods()

print("\n💡 Discuss (1 minute):")
print("Why are periods around 4-10 days 'just right' for life?")
# Out:
# ======================================================================
# 🔍 STEP 2: FIND HABITABLE ZONE PERIODS
# ======================================================================
#
# 📋 ALL PERIODS IN THE DATA:
# --------------------------------------------------
#  1.  1.51 days  ✅ Planet b (hot)
#  2.  2.42 days  ✅ Planet c (hot)
#  3.  3.00 days  ❌ Unknown
#  4.  4.05 days  ✅ Planet d (habitable)
#  5.  6.10 days  ✅ Planet e (habitable)
#  6.  9.21 days  ✅ Planet f (habitable)
#  7. 12.00 days  ❌ Unknown
#
# 💡 DISCUSSION QUESTION (2 minutes with partner):
# Which 3 periods are in the 'Goldilocks Zone' (not too hot, not too cold)?
# Hint: Look for 'habitable' type planets.
#
# --------------------------------------------------
# 🎯 HABITABLE ZONE PLANETS (from NASA):
# --------------------------------------------------
#   TRAPPIST-1d: 4.05 days
#      Temperature: 15°C  🌍
#   TRAPPIST-1e: 6.10 days
#      Temperature: -22°C  ❄️
#   TRAPPIST-1f: 9.21 days
#      Temperature: -54°C  🧊
#
# ✅ KEY INSIGHT:
# Habitable zone = MEDIUM periods (4-10 days)
# Too hot = SHORT periods (<3 days)
# Too cold = LONG periods (>10 days)
# 💡 Discuss (1 minute):
# Why are periods around 4-10 days 'just right' for life?

# %%
# ============================================
# STEP 3: HABITABILITY DASHBOARD
# ============================================

mission.run_habitability_dashboard()

print("\n Try to see if your answers matched. ")
# Out:
# ======================================================================
# 🌡️ STEP 3: HABITABILITY DASHBOARD
# ======================================================================
# /Users/rockyastronaut/Desktop/College/Fall 2025 /CIP/Code Work-/Exoplanet_Workshop/Activity3_Entire_Trappist_System/trappist_habitable.py:572: UserWarning: Glyph 127757 (\N{EARTH GLOBE EUROPE-AFRICA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /Users/rockyastronaut/Desktop/College/Fall 2025 /CIP/Code Work-/Exoplanet_Workshop/Activity3_Entire_Trappist_System/trappist_habitable.py:572: UserWarning: Glyph 129482 (\N{ICE CUBE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /Users/rockyastronaut/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 127757 (\N{EARTH GLOBE EUROPE-AFRICA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/rockyastronaut/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 129482 (\N{ICE CUBE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# 📊 HABITABILITY ASSESSMENT:
# --------------------------------------------------
#
# 🌍 TRAPPIST-1D:
#   Period: 4.05 days
#   Temperature: 15°C
#   Score: 1.00/1.0
#   • Earth-like! Similar to our planet's temperature
#   • Surface liquid water VERY likely
#
# ❄️ TRAPPIST-1E:
#   Period: 6.10 days
#   Temperature: -22°C
#   Score: 0.59/1.0
#   • JWST's primary target for atmosphere study
#   • With CO₂ atmosphere: could be 0-30°C
#
# 🧊 TRAPPIST-1F:
#   Period: 9.21 days
#   Temperature: -54°C
#   Score: 0.30/1.0
#   • Possible subsurface ocean (like Europa)
#   • Ice shell could protect life from radiation
#
# ======================================================================
#
#  Try to see if your answers matched.

# %%
# ============================================
# STEP 4: REAL SCIENCE CONNECTION
# ============================================

mission.real_science_connection()

print("\n🌟 Mind blown? This is ACTUAL science happening NOW!")
# Out:
# ======================================================================
# 🔭 STEP 4: REAL-WORLD SCIENCE CONNECTION
# ======================================================================
#
# 🎯 YOUR ANALYSIS MATTERS BECAUSE:
# 1. JWST is observing TRAPPIST-1 RIGHT NOW
# 2. Searching for water vapor, oxygen, methane in atmospheres
# 3. Could find BIOSIGNATURES (signs of life) in next 5 years!
#
# 📡 CURRENT JWST OBSERVATIONS:
# • TRAPPIST-1e: Primary target (your 'most interesting' planet)
# • Method: Transmission spectroscopy during transits
# • Goal: Detect atmospheric gases that could indicate life
#
# 🌌 WHY THIS IS HISTORIC:
# • First time we can study Earth-sized exoplanet atmospheres
# • Could answer: 'Are we alone in the universe?'
# • Your analysis today used REAL methods scientists use
#
# ======================================================================
# 🏆 MISSION IMPACT:
# ======================================================================
#
# You didn't just complete an exercise.
# You practiced the EXACT methods that might discover
# the first evidence of life beyond Earth.
#
# Keep looking up! 🔭✨
#
# 🌟 Mind blown? This is ACTUAL science happening NOW!

# %%
# ============================================
# STEP 6: SAVE YOUR REPORT
# ============================================

# Change this to your team's name!

team_name = "Team_Alpha"  # ⬅️ EDIT THIS!

mission.save_report(team_name)

print(f"\n📄 Check for file: trappist_report_{team_name}.txt")
print("   Show your instructor or keep as evidence you did real science!")
# Out:
# ✅ REPORT SAVED: trappist_report_Team_Alpha.txt
#    Share with your instructor or keep as a science portfolio piece!
#
# 📄 REPORT PREVIEW:
# --------------------------------------------------
#
# ======================================================================
# TRAPPIST-1 HABITABILITY ANALYSIS REPORT
# ======================================================================
#
# TEAM: Team_Alpha
# DATE: 2025-12-04
# MISSION: Habitable Zone Analysis
#
# ======================================================================
# EXECUTIVE SUMMARY
# ======================================================================
#
# Based on analysis of TRAPPIST-1 system light curve data, our team
# has identified and assessed the three planets within the star's
# ... (full report in file)
#
# 📄 Check for file: trappist_report_Team_Alpha.txt
#    Show your instructor or keep as evidence you did real science!

# %%
# ============================================
# 🎓 OPTIONAL: EXPLORE MORE
# ============================================

# Try these if you finish early:

# 1. Test specific periods
mission.fold_at_period(4.05)
mission.fold_at_period(6.10)

# 2. See the full system
mission.show_full_system()

# 3. Compare to our Solar System  
mission.solar_system_comparison()

# 4. Test your own theory

# Is there a planet at 20 days?
# mission.fold_at_period(20.0)
# Out:
# ✅ Matches TRAPPIST-1d (habitable planet)
# ✅ Matches TRAPPIST-1e (habitable planet)
# ======================================================================
# 🌌 FULL TRAPPIST-1 SYSTEM (7 Planets!)
# ======================================================================
# 🔬 SYSTEM STATS:
# • Total planets: 7
# • Habitable zone planets: 3 (d, e, f)
# • Closest orbit: 1.51 days (b)
# • Farthest orbit: 18.77 days (h)
# • Temperature range: 127°C to -123°C
#
# 🎯 WHY IT'S SPECIAL:
# • Most Earth-sized planets around one star
# • 3 in habitable zone
# • Close enough for detailed study
# • Best candidate for finding life beyond Earth
#
# ======================================================================
# 🌞 COMPARISON: TRAPPIST-1 vs OUR SOLAR SYSTEM
# ======================================================================
# 📏 SCALE COMPARISON:
# • TRAPPIST-1b orbit: 1.51 days
# • Mercury orbit: 88 days
# → TRAPPIST-1 planets are 58x closer to their star!
#
# 🌡️ TEMPERATURE CONTEXT:
# • TRAPPIST-1d: 15°C (Same as Earth!)
# • Venus: 464°C (Runaway greenhouse)
# • Mars: -63°C (Too cold without thick atmosphere)
#
# 💡 KEY INSIGHT:
# Red dwarf stars (like TRAPPIST-1) are smaller and cooler,
# so planets can orbit very close and still be habitable!
