# %%
# 🌍 ACTIVITY 1: KEPLER-22B DETECTIVE")

# MISSION:
#• Find and analyze Kepler-22b
#• First Earth-sized planet in a habitable zone!
#• Use interactive tools to characterize it

# TOOLS: 
#• Interactive slider fitting
#• Real-time analysis"
#• Planet classification


# Import the toolkit. This file contains all the code of this activity.
# The toolkit code must not be altered. 

from kepler22_lab import Kepler_Tool

# Create your lab 

lab = Kepler_Tool()
print("✅ Detective lab ready!")


# 📂 LOADING TELESCOPE DATA
# This data comes from NASA's Kepler Space Telescope
# It shows brightness measurements of star Kepler-22
# over 4 years of observations

# Load the data from the provided file, using toolkit. 
time, brightness = lab.load_data("kepler22b_data.csv")

#Visualize the data 

lab.plot_light_curve(time, brightness)

print("\n✅ DATA LOADED!")
print(f"• Look for repeating dips in brightness!")
print("• Try to classify depth of transit!")

# %%
# ============================================================================
# FIRST LOOK - WHAT DO YOU SEE?
# ============================================================================

# Discuss with your partner. 

print("🔍 FIRST ANALYSIS")

print("\n QUESTIONS TO CONSIDER:")
print("1. Can you see any patterns?")
print("2. Are there repeating 'dips' in brightness?")
print("3. How often do they occur?")
print("4. How deep are the dips?")
print("\nWrite your observations below:")

# Just look at the plot from Cell 2
# No new code needed here

# Write your observations below. 


print("\n📝 MY OBSERVATIONS:")
print("__________________________________________________")
print("__________________________________________________")
print("__________________________________________________")

# %%
# ============================================================================
# INTERACTIVE PLANET HUNT
# ============================================================================

#HOW TO USE:
# 1. Adjust the THREE sliders below
# 2. Watch the fit update in REAL-TIME
# 3. Try to MAXIMIZE your score (aim for >40/80)

# The analysis panels show what you're finding!

# SLIDER GUIDE:
#• Planet Size: How big is the planet?
#• Orbital Period: How often does it orbit?
#• Orbital Speed: How fast does it transit?


# Start the interactive hunt (just 1 line!)
lab.interactive_fit(time, brightness)  # ← This will work with your Kepler_Tool class

# 💡 TIPS:
#• Start with Period ~290 days
#• Adjust Size to match dip depth
#• Watch the 'Planet Properties' panel update!
